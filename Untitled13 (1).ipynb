# %% [markdown]
# # 1. string.capitalize()

# %%
string ="PYTHON"
print(string.capitalize())
# Out:
# Python

# %% [markdown]
# # 2. string.casefold()

# %%
string  = "PYTHON"
print(string.casefold())
# Out:
# python

# %% [markdown]
# # 3.string.islower()

# %%
string ="python"
print(string.islower())
string ="PYTHON"
print(string.islower())
# Out:
# True
# False

# %% [markdown]
# # 4.string.lower()

# %%
string ="PYTHON"
print(string.lower())
# Out:
# python

# %% [markdown]
#  # 5.string.upper()

# %%
string ="python"
print(string.upper())
# Out:
# PYTHON

# %% [markdown]
#  # 6.string.title()

# %%
string =" i  learn python"
print(string.title())
# Out:
#  I  Learn Python

# %% [markdown]
# # 7. string.swapcase()

# %%
string ="PYTHon"
print(string.swapcase())
# Out:
# pythON

# %% [markdown]
# # 8.string.strip()

# %%
string  ="    deepanshu pal   "
print(string)
print(string.strip())
# Out:
#     deepanshu pal
# deepanshu pal

# %%
string ="@@@@python"
print(string.strip("@"))
# Out:
# python

# %% [markdown]
# # 9.string.lstrip()

# %%
string ="@@python"
print(string.lstrip("@"))
# Out:
# python

# %% [markdown]
# # 10.string.rstrip()

# %%
string = "python###"
print(string.rstrip("#"))
# Out:
# python

# %% [markdown]
#  # 11.string.replace()

# %%
string1="java"
string2 ="python"
print(string1.replace(string1,string2))
# Out:
# python

# %% [markdown]
# # 12.string.find()

# %%
string ="Python i learn java "
print(string.find("java"))
len(string) -len("java")
# Out:
# 15
# 16

# %% [markdown]
# ## # 13.string.index()

# %%
string ="i learn python"
print(string.index("p"))
# Out:
# 8

# %% [markdown]
# # 14.string.rindex()

# %%
string =" banana"
print(string.rindex("a"))
# Out:
# 6

# %% [markdown]
# # 16.string.startswith()

# %%
string ="deepanshu976162@gmail.com"
print(string.startswith("deepanshu976162"))
# Out:
# True

# %% [markdown]
# # 17.string.endswith()

# %%
string ="deepanshu000@gmail.com"
print(string.endswith("@gmail.com"))
# Out:
# True

# %% [markdown]
# # 18.string.isalnum()

# %%
string ="123abc"
print(string.isalnum())
# Out:
# True

# %% [markdown]
# # 19.string.isalpha()

# %%
string ="abc"
print(string.isalpha())
# Out:
# True

# %% [markdown]
# # 20.string.isdigit()

# %%
string ="1129"
print(string.isdigit())
# Out:
# True

# %% [markdown]
# # 21.string.isspace()

# %%
string ="\n"
print(string.isspace())
# Out:
# True

# %% [markdown]
# # 22.string.isdecimal()

# %%
string ="12344553665"
print(string.isdecimal())
# Out:
# True

# %% [markdown]
# # 23.string.isnumeric()

# %%
string ="124"
print(string.isnumeric())
# Out:
# True

# %% [markdown]
# # 24.string.isidentifier()

# %%
string ="var1"
print(string.isidentifier())
# Out:
# True

# %% [markdown]
# # 25.string.isprintable()

# %%
string ="deepak00"
print(string.isprintable())
string ="\n"
print(string.isprintable())
# Out:
# True
# False

# %% [markdown]
# # 27.string.splitlines()

# %%
string ="hello\nword\npython"
print(string.splitlines())
print(string.splitlines(True))
# Out:
# ['hello', 'word', 'python']
# ['hello\n', 'word\n', 'python']

# %% [markdown]
# # 28.string.join()

# %% [markdown]
# # 29.string.format()

# %%
string =" deepanshu"
age  = 23
print("my name is{0} my age {1}".format(string, age))
# Out:
# my name is deepanshu my age 23

# %% [markdown]
# # 30.string.format_map()

# %%
string ={"name" : "deepanshu ","age" : 21} 
print("Name:{name} , Age:{age}".format_map(string))
# Out:
# Name:deepanshu  , Age:21

# %% [markdown]
# # 31.string.center()

# %%
string ="python"
print(string.center(10," " ))
print(string.center(10,"#"))
# Out:
#   python
# ##python##

# %% [markdown]
# # 32.string.ljust()

# %%
string ="deepak"
print(string.ljust(10,"#"))
# Out:
# deepak####

# %% [markdown]
# # 33. string.rjust()

# %%
string ="deepak"
print(string.rjust(10,"#"))
print(string.rjust(10," "))
# Out:
# ####deepak
#     deepak

# %% [markdown]
# # 34.string.zfill()

# %%
string ="2"
print(string.zfill(9))
len(string.zfill(9))
# Out:
# 000000002
# 9

# %% [markdown]
# # 35.string.encode()

# %% [markdown]
# # 36.string.expandtabs()

# %%
string ="java\texcel\tjava"
print(string.expandtabs(50))
# Out:
# java                                              excel                                             java

# %% [markdown]
# # 37.string.partition()

# %%
string =" hello word"
print(string.partition( " "))
# Out:
# ('', ' ', 'hello word')

# %% [markdown]
# # 38.string.rpartition()

# %% [markdown]
# # 39.string.translate()

# %%
table = str.maketrans("abcp","1234")
text =" abc apple"
result = text.translate(table)
print(result)
# Out:
#  123 144le

# %% [markdown]
# # 40.string.split()

# %%
string ="deepanshu pal "
print(string.split())
string ="  "
# Out:
# ['deepanshu', 'pal']

# %% [markdown]
# # 41.string.join()

# %% [markdown]
# # 42.string.islower()

# %%
string ="python"
print(string.islower())
# Out:
# True

# %%
text ="123#"
print(text.isascii())
# Out:
# True

# %% [markdown]
# # 43.string.removeprefix()

# %%
string ="hello word"
print(string.removeprefix("hello"))
# Out:
#  word

# %% [markdown]
# # 43.string.removeprefix()

# %%
string ="hello word"
print(string.removesuffix("word"))
# Out:
# hello
